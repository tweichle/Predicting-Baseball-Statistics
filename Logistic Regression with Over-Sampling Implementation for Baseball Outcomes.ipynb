# %%
import numpy as np
import pandas as pd
from pandas.plotting import autocorrelation_plot
from math import sqrt
import scipy as sp
from scipy import stats
import scipy.signal
from scipy.signal import fftconvolve, convolve
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact
import random as ran

from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import *

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV, LogisticRegression
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer, ENGLISH_STOP_WORDS
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.pipeline import make_pipeline
from sklearn import metrics
from sklearn import datasets
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from textacy.preprocess import preprocess_text

from gensim import corpora, models, matutils
from collections import defaultdict, Counter

import statsmodels.api as sm
import statsmodels.formula.api as sm
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX

import tensorflow as tf

import patsy
from itertools import combinations

from imblearn.over_sampling import SMOTE

import graphviz
import json
import requests
import urllib
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import re
import twitter

# %matplotlib inline
#plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Build and document a working model, prototype, recommendation, or solution

# %% [markdown]
# Note: The new Statcast metrics are available beginning from the 2015 baseball season to the current season. I downloaded the 2015-2017 baseball season data for all teams which will be used in the data modeling.

# %% [markdown]
# ## [pybaseball](https://github.com/jldbc/pybaseball)
# Pull current and historical baseball statistics using Python (Statcast, Baseball Reference, FanGraphs)
#
# `pybaseball` is a Python package for baseball data analysis. This package scrapes Baseball Reference, Baseball Savant, and FanGraphs so you don't have to. The package retrieves statcast data, pitching stats, batting stats, division standings/team records, awards data, and more. Data is available at the individual pitch level, as well as aggregated at the season level and over custom time periods. See the [docs](https://github.com/jldbc/pybaseball/tree/master/docs) for a comprehensive list of data acquisition functions.

# %% [markdown]
# **Statcast**
#
# The statcast function retrieves pitch-level statcast data for a given date or range or dates.
#
# statcast(start_dt=[yesterday's date], end_dt=None, team=None)

# %%
# Pull advanced metrics from Major League Baseball's Statcast system
#from pybaseball import statcast

# Look up a player's MLBAM, Retrosheet, FanGraphs, and Baseball Reference ID by name
#from pybaseball import playerid_lookup

# %% [markdown]
# ### Reading a File

# %%
# Create data path variable for loading data
data_path = '/Users/yangweichle/Documents/GeneralAssembly/Projects/Datasets/'

# %%
# Read file into DataFrame
# Note: header=0 disables the header from the file
all_MLB_teams2015_2017 = pd.read_csv(data_path + 'all_MLB_teams2015_2017.csv', header=0) # Comma-separated values file

# %% [markdown]
# ### Examine the DataFrame

# %%
# Return the number of rows and columns (dimensionality) of the DataFrame
print('Rows: {}, Cols: {}'.format(all_MLB_teams2015_2017.shape[0], all_MLB_teams2015_2017.shape[1]))
# Out:
# Rows: 2139920, Cols: 91

# %%
# Print a concise summary of a DataFrame including the index dtype and column dtypes, non-null values, and memory usage
# Note: Useful to quickly see if null values exist 
all_MLB_teams2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139920 entries, 0 to 2139919
# Data columns (total 91 columns):
# Unnamed: 0                         int64
# index                              int64
# pitch_type                         object
# game_date                          object
# release_speed                      float64
# release_pos_x                      float64
# release_pos_z                      float64
# player_name                        object
# batter                             float64
# pitcher                            float64
# events                             object
# description                        object
# spin_dir                           float64
# spin_rate_deprecated               float64
# break_angle_deprecated             float64
# break_length_deprecated            float64
# zone                               float64
# des                                object
# game_type                          object
# stand                              object
# p_throws                           object
# home_team                          object
# away_team                          object
# type                               object
# hit_location                       float64
# bb_type                            object
# balls                              float64
# strikes                            float64
# game_year                          float64
# pfx_x                              float64
# pfx_z                              float64
# plate_x                            float64
# plate_z                            float64
# on_3b                              float64
# on_2b                              float64
# on_1b                              float64
# outs_when_up                       float64
# inning                             float64
# inning_topbot                      object
# hc_x                               float64
# hc_y                               float64
# tfs_deprecated                     float64
# tfs_zulu_deprecated                float64
# pos2_person_id                     float64
# umpire                             float64
# sv_id                              object
# vx0                                float64
# vy0                                float64
# vz0                                float64
# ax                                 float64
# ay                                 float64
# az                                 float64
# sz_top                             float64
# sz_bot                             float64
# hit_distance_sc                    float64
# launch_speed                       float64
# launch_angle                       float64
# effective_speed                    float64
# release_spin_rate                  float64
# release_extension                  float64
# game_pk                            float64
# pos1_person_id                     float64
# pos2_person_id.1                   float64
# pos3_person_id                     float64
# pos4_person_id                     float64
# pos5_person_id                     float64
# pos6_person_id                     float64
# pos7_person_id                     float64
# pos8_person_id                     float64
# pos9_person_id                     float64
# release_pos_y                      float64
# estimated_ba_using_speedangle      float64
# estimated_woba_using_speedangle    float64
# woba_value                         float64
# woba_denom                         float64
# babip_value                        float64
# iso_value                          float64
# launch_speed_angle                 float64
# at_bat_number                      float64
# pitch_number                       float64
# pitch_name                         object
# home_score                         float64
# away_score                         float64
# bat_score                          float64
# fld_score                          float64
# post_away_score                    float64
# post_home_score                    float64
# post_bat_score                     float64
# post_fld_score                     float64
# if_fielding_alignment              object
# of_fielding_alignment              object
# dtypes: float64(71), int64(2), object(18)
# memory usage: 1.5+ GB

# %%
# Column names (which is "an index")
#all_MLB_teams2015_2017.columns

# %%
# Sort a DataFrame by multiple columns
# Note: ascending: sort ascending vs. descending; ascending=True is default
#       inplace=True changes the original DataFrame
all_MLB_teams2015_2017.sort_values(by=['game_date', 'game_pk', 'at_bat_number', 'pitch_number'], ascending=True, inplace=True)

# %%
# Print the first 5 rows and the last 5 rows of the DataFrame
all_MLB_teams2015_2017.head().append(all_MLB_teams2015_2017.tail())
# Out:
#          Unnamed: 0  index pitch_type   game_date  release_speed  \
# 2139919      702491  17584         FF  2015-04-05           93.6
# 2139918      702490  17583         FF  2015-04-05           93.4
# 2139917      702489  17582         FF  2015-04-05           94.8
# 2139916      702488  17581         FF  2015-04-05           91.6
# 2139915      702487  17580         CU  2015-04-05           75.9
# 4                 4    650         FT  2017-10-01           95.9
# 3                 3    636         CH  2017-10-01           82.8
# 2                 2    620         FF  2017-10-01           94.7
# 1                 1    615         FC  2017-10-01           91.8
# 0                 0    597         FC  2017-10-01           91.9
#
#          release_pos_x  release_pos_z    player_name    batter   pitcher  \
# 2139919         2.5520         5.5293     Jon Lester  572761.0  452657.0
# 2139918         2.5694         5.6476     Jon Lester  572761.0  452657.0
# 2139917         2.6266         5.2936     Jon Lester  572761.0  452657.0
# 2139916            NaN            NaN     Jon Lester  572761.0  452657.0
# 2139915            NaN            NaN     Jon Lester  572761.0  452657.0
# 4              -0.8903         6.1341  Roberto Osuna  595885.0  532077.0
# 3              -0.9901         6.0626  Roberto Osuna  595885.0  532077.0
# 2              -0.6208         6.3387  Roberto Osuna  595885.0  532077.0
# 1              -1.0777         6.1772  Roberto Osuna  595885.0  532077.0
# 0              -1.1948         5.9921  Roberto Osuna  595885.0  532077.0
#
#                  ...          home_score away_score  bat_score  fld_score  \
# 2139919          ...                 0.0        0.0        0.0        0.0
# 2139918          ...                 0.0        0.0        0.0        0.0
# 2139917          ...                 0.0        0.0        0.0        0.0
# 2139916          ...                 0.0        0.0        0.0        0.0
# 2139915          ...                 0.0        0.0        0.0        0.0
# 4                ...                 1.0        2.0        1.0        2.0
# 3                ...                 1.0        2.0        1.0        2.0
# 2                ...                 1.0        2.0        1.0        2.0
# 1                ...                 1.0        2.0        1.0        2.0
# 0                ...                 1.0        2.0        1.0        2.0
#
#          post_away_score  post_home_score  post_bat_score post_fld_score  \
# 2139919              0.0              0.0             0.0            0.0
# 2139918              0.0              0.0             0.0            0.0
# 2139917              0.0              0.0             0.0            0.0
# 2139916              0.0              0.0             0.0            0.0
# 2139915              0.0              0.0             0.0            0.0
# 4                    2.0              1.0             1.0            2.0
# 3                    2.0              1.0             1.0            2.0
# 2                    2.0              1.0             1.0            2.0
# 1                    2.0              1.0             1.0            2.0
# 0                    2.0              1.0             1.0            2.0
#
#         if_fielding_alignment of_fielding_alignment
# 2139919                   NaN                   NaN
# 2139918                   NaN                   NaN
# 2139917                   NaN                   NaN
# 2139916                   NaN                   NaN
# 2139915                   NaN                   NaN
# 4               Infield shift             Strategic
# 3               Infield shift             Strategic
# 2               Infield shift             Strategic
# 1               Infield shift             Strategic
# 0                         NaN                   NaN
#
# [10 rows x 91 columns]

# %% [markdown]
# #### Identifying important columns to include in the DataFrame.

# %%
# Select multiple columns
# Note: release_speed = Pitch Velocity (MPH)
#       bb_type = Batted Ball Type
#       launch_speed = Exit Velocity (MPH)
#       launch_angle = Launch Angle (Degrees)
baseball_cols = ['game_date', 'home_team', 'away_team', 'player_name', 'pitcher', 'pitch_type', 'pitch_name', 'release_speed',
                 'batter', 'events', 'description', 'bb_type', 'des', 'launch_speed', 'launch_angle', 'hit_distance_sc'] 
all_MLB_teams2015_2017_new = all_MLB_teams2015_2017[baseball_cols]

# %%
# Return the number of rows and columns (dimensionality) of the DataFrame
print('Rows: {}, Cols: {}'.format(all_MLB_teams2015_2017_new.shape[0], all_MLB_teams2015_2017_new.shape[1]))
# Out:
# Rows: 2139920, Cols: 16

# %%
# Print the first 5 rows of the DataFrame
all_MLB_teams2015_2017_new.head()
# Out:
#           game_date home_team away_team player_name   pitcher pitch_type  \
# 2139919  2015-04-05       CHC       STL  Jon Lester  452657.0         FF
# 2139918  2015-04-05       CHC       STL  Jon Lester  452657.0         FF
# 2139917  2015-04-05       CHC       STL  Jon Lester  452657.0         FF
# 2139916  2015-04-05       CHC       STL  Jon Lester  452657.0         FF
# 2139915  2015-04-05       CHC       STL  Jon Lester  452657.0         CU
#
#               pitch_name  release_speed    batter events      description  \
# 2139919  4-Seam Fastball           93.6  572761.0    NaN    called_strike
# 2139918  4-Seam Fastball           93.4  572761.0    NaN  swinging_strike
# 2139917  4-Seam Fastball           94.8  572761.0    NaN             foul
# 2139916  4-Seam Fastball           91.6  572761.0    NaN             ball
# 2139915        Curveball           75.9  572761.0    NaN             ball
#
#         bb_type  des  launch_speed  launch_angle  hit_distance_sc
# 2139919     NaN  NaN           NaN           NaN              NaN
# 2139918     NaN  NaN           NaN           NaN              NaN
# 2139917     NaN  NaN           NaN           NaN              NaN
# 2139916     NaN  NaN           NaN           NaN              NaN
# 2139915     NaN  NaN           NaN           NaN              NaN

# %%
# Rename one or more columns in the original DataFrame rather than returning a new view
all_MLB_teams2015_2017_new = all_MLB_teams2015_2017_new.rename(columns={'release_speed': 'pitch_velocity',
                                                                        'bb_type': 'batted_ball_type',
                                                                        'launch_speed': 'exit_velocity'})

# %%
# Print a concise summary of a DataFrame including the index dtype and column dtypes, non-null values, and memory usage
# Note: Useful to quickly see if null values exist 
all_MLB_teams2015_2017_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2139920 entries, 2139919 to 0
# Data columns (total 16 columns):
# game_date           object
# home_team           object
# away_team           object
# player_name         object
# pitcher             float64
# pitch_type          object
# pitch_name          object
# pitch_velocity      float64
# batter              float64
# events              object
# description         object
# batted_ball_type    object
# des                 object
# exit_velocity       float64
# launch_angle        float64
# hit_distance_sc     float64
# dtypes: float64(6), object(10)
# memory usage: 277.5+ MB

# %% [markdown]
# ### Handling Missing Values

# %%
# Count the missing values in each column of a DataFrame - sum() works because True is 1 and False is 0
all_MLB_teams2015_2017_new.isnull().sum()
# Out:
# game_date                 0
# home_team                 0
# away_team                 0
# player_name               0
# pitcher                   0
# pitch_type             3814
# pitch_name             3814
# pitch_velocity         2505
# batter                    0
# events              1586052
# description               0
# batted_ball_type    1752979
# des                 1586054
# exit_velocity       1585044
# launch_angle        1585019
# hit_distance_sc     1631442
# dtype: int64

# %%
# Create a vertical bar plot by number of missing values per column using matplotlib
# Note: figsize: a tuple (width, height) in inches
all_MLB_teams2015_2017_new.isnull().sum().plot.bar(figsize=(10, 8));
plt.title('Number of null values per column');

# %% [markdown]
# #### Approach for excluding records:

# %% [markdown]
# Each record represents an interaction between a pitcher and a batter (i.e., a pitch thrown by the pitcher to the batter).  The goal is to keep any interaction for which Statcast could provide valid measurements for the metrics `launch_speed`, `launch_angle`, and `hit_distance_sc`.
#
# In order to do so, non-batted ball records will be excluded. <br>
#
# - Drop all `events` = NaN which represent interactions where the batter did not make contact with the ball or the batter made contact with the ball but it was hit foul (e.g., ball, foul, called strike, swinging strike, blocked ball, foul tip, intentional ball, foul bunt, swinging strike blocked, missed bunt, pitchout)
#
# - Drop all `batted_ball_type` = NaN which represents other remaining events where there was not a batted ball (e.g., strikeout, walk, hit by pitch, intentional walk, caught stealing, etc.)

# %% [markdown]
# #### Examine `events` column for missingness.

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new.events.value_counts(dropna=False)
# Out:
# NaN                             1586052
# field_out                        223381
# strikeout                        116120
# single                            82491
# walk                              42138
# double                            24898
# home_run                          16629
# force_out                         11500
# grounded_into_double_play         11266
# hit_by_pitch                       5019
# field_error                        4816
# sac_fly                            3549
# sac_bunt                           3149
# triple                             2607
# intent_walk                        1884
# double_play                        1348
# fielders_choice_out                 919
# caught_stealing_2b                  696
# strikeout_double_play               435
# fielders_choice                     301
# pickoff_caught_stealing_2b          131
# other_out                           120
# catcher_interf                      113
# pickoff_1b                           95
# sac_fly_double_play                  66
# caught_stealing_3b                   56
# pickoff_2b                           55
# caught_stealing_home                 29
# triple_play                          18
# run                                  16
# pickoff_caught_stealing_3b           10
# batter_interference                   4
# pickoff_caught_stealing_home          3
# sac_bunt_double_play                  3
# pickoff_3b                            3
# Name: events, dtype: int64

# %%
# Detect missing values in a Series
# Note: True if missing, False if not missing
#cubs2016_new.events.isna() # alias of isnull()
null_events = all_MLB_teams2015_2017_new.events.isnull()
all_MLB_teams2015_2017_new[null_events]
# Out:
#           game_date home_team away_team      player_name   pitcher pitch_type  \
# 2139919  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139918  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139917  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139916  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139915  2015-04-05       CHC       STL       Jon Lester  452657.0         CU
# 2139913  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139911  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139910  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139908  2015-04-05       CHC       STL       Jon Lester  452657.0         SI
# 2139907  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139905  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139904  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139903  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139902  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139900  2015-04-05       CHC       STL  Adam Wainwright  425794.0         SI
# 2139898  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FF
# 2139897  2015-04-05       CHC       STL  Adam Wainwright  425794.0         CU
# 2139896  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FC
# 2139894  2015-04-05       CHC       STL  Adam Wainwright  425794.0         CU
# 2139893  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FC
# 2139892  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FF
# 2139891  2015-04-05       CHC       STL  Adam Wainwright  425794.0         CU
# 2139889  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FC
# 2139888  2015-04-05       CHC       STL  Adam Wainwright  425794.0         CU
# 2139887  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FF
# 2139885  2015-04-05       CHC       STL       Jon Lester  452657.0         FC
# 2139884  2015-04-05       CHC       STL       Jon Lester  452657.0         FC
# 2139883  2015-04-05       CHC       STL       Jon Lester  452657.0         CH
# 2139881  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139880  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# ...             ...       ...       ...              ...       ...        ...
# 36       2017-10-01       NYY       TOR      Ryan Tepera  572193.0         FC
# 35       2017-10-01       NYY       TOR      Ryan Tepera  572193.0         FC
# 34       2017-10-01       NYY       TOR      Ryan Tepera  572193.0         SI
# 33       2017-10-01       NYY       TOR      Ryan Tepera  572193.0         FC
# 31       2017-10-01       NYY       TOR       Ben Heller  621294.0         FF
# 30       2017-10-01       NYY       TOR       Ben Heller  621294.0         CU
# 28       2017-10-01       NYY       TOR       Ben Heller  621294.0         FF
# 27       2017-10-01       NYY       TOR       Ben Heller  621294.0         FF
# 26       2017-10-01       NYY       TOR       Ben Heller  621294.0         CU
# 24       2017-10-01       NYY       TOR       Ben Heller  621294.0         FF
# 23       2017-10-01       NYY       TOR       Ben Heller  621294.0         CH
# 22       2017-10-01       NYY       TOR       Ben Heller  621294.0         CH
# 21       2017-10-01       NYY       TOR       Ben Heller  621294.0         FF
# 20       2017-10-01       NYY       TOR       Ben Heller  621294.0         CU
# 19       2017-10-01       NYY       TOR       Ben Heller  621294.0         FF
# 17       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FT
# 16       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FT
# 15       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 14       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 13       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 11       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FC
# 10       2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 9        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 8        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 7        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FC
# 5        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 4        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FT
# 3        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         CH
# 2        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FF
# 1        2017-10-01       NYY       TOR    Roberto Osuna  532077.0         FC
#
#               pitch_name  pitch_velocity    batter events      description  \
# 2139919  4-Seam Fastball            93.6  572761.0    NaN    called_strike
# 2139918  4-Seam Fastball            93.4  572761.0    NaN  swinging_strike
# 2139917  4-Seam Fastball            94.8  572761.0    NaN             foul
# 2139916  4-Seam Fastball            91.6  572761.0    NaN             ball
# 2139915        Curveball            75.9  572761.0    NaN             ball
# 2139913  4-Seam Fastball            94.0  518792.0    NaN             ball
# 2139911  4-Seam Fastball            92.7  407812.0    NaN             ball
# 2139910  4-Seam Fastball            89.9  407812.0    NaN             ball
# 2139908           Sinker            91.1  425509.0    NaN             foul
# 2139907  4-Seam Fastball            91.2  425509.0    NaN             foul
# 2139905  4-Seam Fastball            92.2  571431.0    NaN             ball
# 2139904  4-Seam Fastball            93.8  571431.0    NaN             foul
# 2139903  4-Seam Fastball            91.7  571431.0    NaN             foul
# 2139902  4-Seam Fastball            93.0  571431.0    NaN             foul
# 2139900           Sinker            90.1  451594.0    NaN             ball
# 2139898  4-Seam Fastball            92.2  624585.0    NaN             foul
# 2139897        Curveball            76.6  624585.0    NaN     blocked_ball
# 2139896           Cutter            87.8  624585.0    NaN  swinging_strike
# 2139894        Curveball            77.0  519203.0    NaN     blocked_ball
# 2139893           Cutter            88.6  519203.0    NaN  swinging_strike
# 2139892  4-Seam Fastball            92.4  519203.0    NaN    called_strike
# 2139891        Curveball            78.1  519203.0    NaN     blocked_ball
# 2139889           Cutter            89.4  516770.0    NaN     blocked_ball
# 2139888        Curveball            76.5  516770.0    NaN             ball
# 2139887  4-Seam Fastball            92.3  516770.0    NaN             foul
# 2139885           Cutter            87.9  425877.0    NaN             ball
# 2139884           Cutter            87.5  425877.0    NaN  swinging_strike
# 2139883         Changeup            83.7  425877.0    NaN  swinging_strike
# 2139881  4-Seam Fastball            91.8  543939.0    NaN  swinging_strike
# 2139880  4-Seam Fastball            93.4  543939.0    NaN             ball
# ...                  ...             ...       ...    ...              ...
# 36                Cutter            89.9  591720.0    NaN             ball
# 35                Cutter            89.6  591720.0    NaN             ball
# 34                Sinker            94.8  591720.0    NaN             foul
# 33                Cutter            90.5  591720.0    NaN             foul
# 31       4-Seam Fastball            95.2  620446.0    NaN    called_strike
# 30             Curveball            83.2  620446.0    NaN  swinging_strike
# 28       4-Seam Fastball            95.5  475253.0    NaN    called_strike
# 27       4-Seam Fastball            96.6  475253.0    NaN  swinging_strike
# 26             Curveball            83.4  475253.0    NaN             ball
# 24       4-Seam Fastball            96.0  459431.0    NaN    called_strike
# 23              Changeup            85.6  459431.0    NaN             ball
# 22              Changeup            85.7  459431.0    NaN             ball
# 21       4-Seam Fastball            94.1  459431.0    NaN             foul
# 20             Curveball            81.2  459431.0    NaN             ball
# 19       4-Seam Fastball            94.3  459431.0    NaN             foul
# 17       2-Seam Fastball            93.3  642180.0    NaN    called_strike
# 16       2-Seam Fastball            94.9  642180.0    NaN  swinging_strike
# 15       4-Seam Fastball            96.1  642180.0    NaN             ball
# 14       4-Seam Fastball            96.1  642180.0    NaN             ball
# 13       4-Seam Fastball            94.9  642180.0    NaN             ball
# 11                Cutter            91.7  407812.0    NaN             ball
# 10       4-Seam Fastball            95.4  407812.0    NaN  swinging_strike
# 9        4-Seam Fastball            95.6  407812.0    NaN    called_strike
# 8        4-Seam Fastball            96.7  407812.0    NaN             foul
# 7                 Cutter            91.0  407812.0    NaN             foul
# 5        4-Seam Fastball            96.0  595885.0    NaN    called_strike
# 4        2-Seam Fastball            95.9  595885.0    NaN             ball
# 3               Changeup            82.8  595885.0    NaN             ball
# 2        4-Seam Fastball            94.7  595885.0    NaN             ball
# 1                 Cutter            91.8  595885.0    NaN             foul
#
#         batted_ball_type  des  exit_velocity  launch_angle  hit_distance_sc
# 2139919              NaN  NaN            NaN           NaN              NaN
# 2139918              NaN  NaN            NaN           NaN              NaN
# 2139917              NaN  NaN            NaN           NaN              NaN
# 2139916              NaN  NaN            NaN           NaN              NaN
# 2139915              NaN  NaN            NaN           NaN              NaN
# 2139913              NaN  NaN           92.6       10.5026            186.0
# 2139911              NaN  NaN            NaN           NaN              NaN
# 2139910              NaN  NaN            NaN           NaN              NaN
# 2139908              NaN  NaN            NaN           NaN              NaN
# 2139907              NaN  NaN          101.5        6.2577            186.0
# 2139905              NaN  NaN           70.4       52.9968            198.0
# 2139904              NaN  NaN            NaN           NaN              NaN
# 2139903              NaN  NaN            NaN           NaN              NaN
# 2139902              NaN  NaN            NaN           NaN              NaN
# 2139900              NaN  NaN            NaN           NaN              NaN
# 2139898              NaN  NaN           92.1       17.2619            267.0
# 2139897              NaN  NaN            NaN           NaN              NaN
# 2139896              NaN  NaN            NaN           NaN              NaN
# 2139894              NaN  NaN            NaN           NaN              NaN
# 2139893              NaN  NaN            NaN           NaN              NaN
# 2139892              NaN  NaN            NaN           NaN              NaN
# 2139891              NaN  NaN            NaN           NaN              NaN
# 2139889              NaN  NaN            NaN           NaN              NaN
# 2139888              NaN  NaN            NaN           NaN              NaN
# 2139887              NaN  NaN            NaN           NaN              NaN
# 2139885              NaN  NaN            NaN           NaN              NaN
# 2139884              NaN  NaN            NaN           NaN              NaN
# 2139883              NaN  NaN            NaN           NaN              NaN
# 2139881              NaN  NaN            NaN           NaN              NaN
# 2139880              NaN  NaN            NaN           NaN              NaN
# ...                  ...  ...            ...           ...              ...
# 36                   NaN  NaN            NaN           NaN              NaN
# 35                   NaN  NaN            NaN           NaN              NaN
# 34                   NaN  NaN           78.8       14.6549            158.0
# 33                   NaN  NaN           38.1      -44.9208              2.0
# 31                   NaN  NaN            NaN           NaN              NaN
# 30                   NaN  NaN            NaN           NaN              NaN
# 28                   NaN  NaN            NaN           NaN              NaN
# 27                   NaN  NaN            NaN           NaN              NaN
# 26                   NaN  NaN            NaN           NaN              NaN
# 24                   NaN  NaN            NaN           NaN              NaN
# 23                   NaN  NaN            NaN           NaN              NaN
# 22                   NaN  NaN            NaN           NaN              NaN
# 21                   NaN  NaN            NaN           NaN              NaN
# 20                   NaN  NaN            NaN           NaN              NaN
# 19                   NaN  NaN           68.1       56.6264            182.0
# 17                   NaN  NaN            NaN           NaN              NaN
# 16                   NaN  NaN            NaN           NaN              NaN
# 15                   NaN  NaN            NaN           NaN              NaN
# 14                   NaN  NaN            NaN           NaN              NaN
# 13                   NaN  NaN            NaN           NaN              NaN
# 11                   NaN  NaN            NaN           NaN              NaN
# 10                   NaN  NaN            NaN           NaN              NaN
# 9                    NaN  NaN            NaN           NaN              NaN
# 8                    NaN  NaN           54.7       46.1744            137.0
# 7                    NaN  NaN           71.6       46.2232            202.0
# 5                    NaN  NaN            NaN           NaN              NaN
# 4                    NaN  NaN            NaN           NaN              NaN
# 3                    NaN  NaN            NaN           NaN              NaN
# 2                    NaN  NaN           75.0       -7.6433             20.0
# 1                    NaN  NaN            NaN           NaN              NaN
#
# [1586052 rows x 16 columns]

# %% [markdown]
# #### What types of interactions occurred for missing `events`?

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new[null_events].description.value_counts(dropna=False)
# Out:
# ball                       676751
# foul                       371731
# called_strike              333190
# swinging_strike            131229
# blocked_ball                45367
# foul_tip                    10704
# foul_bunt                    6228
# intent_ball                  4724
# swinging_strike_blocked      4312
# missed_bunt                  1299
# pitchout                      510
# swinging_pitchout               4
# foul_pitchout                   1
# hit_into_play_score             1
# hit_into_play                   1
# Name: description, dtype: int64

# %% [markdown]
# #### Drop missing values from `events` column.

# %%
# Remove missing values
# Note: axis=0 (default) drop rows which contain missing values
#       how='any' (default) drops rows if ANY missing values are present from any column -- can be dangerous!
#       subset: if you are dropping rows these would be a list of columns to include
#       inplace=True changes the original DataFrame
all_MLB_teams2015_2017_new.dropna(subset=['events'], inplace=True)

# %% [markdown]
# #### Examine `batted_ball_type` column for missingness.

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new.batted_ball_type.value_counts(dropna=False)
# Out:
# ground_ball    178646
# NaN            166927
# line_drive      99714
# fly_ball        81752
# popup           26829
# Name: batted_ball_type, dtype: int64

# %%
# Detect missing values in a Series
# Note: True if missing, False if not missing
#all_MLB_teams2015_2017_new.batted_ball_type.isna() # alias of isnull()
null_batted_ball_type = all_MLB_teams2015_2017_new.batted_ball_type.isnull()
all_MLB_teams2015_2017_new[null_batted_ball_type]
# Out:
#           game_date home_team away_team        player_name   pitcher  \
# 2139906  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139901  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139890  2015-04-05       CHC       STL    Adam Wainwright  425794.0
# 2139882  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139875  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139866  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139864  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139854  2015-04-05       CHC       STL    Adam Wainwright  425794.0
# 2139849  2015-04-05       CHC       STL    Adam Wainwright  425794.0
# 2139837  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139814  2015-04-05       CHC       STL    Adam Wainwright  425794.0
# 2139808  2015-04-05       CHC       STL    Adam Wainwright  425794.0
# 2139803  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139792  2015-04-05       CHC       STL         Jon Lester  452657.0
# 2139763  2015-04-05       CHC       STL          Phil Coke  457435.0
# 2139759  2015-04-05       CHC       STL          Phil Coke  457435.0
# 2139755  2015-04-05       CHC       STL          Phil Coke  457435.0
# 2139737  2015-04-05       CHC       STL    Adam Wainwright  425794.0
# 2139701  2015-04-05       CHC       STL       Neil Ramirez  519166.0
# 2139687  2015-04-05       CHC       STL    Carlos Martinez  593372.0
# 2139681  2015-04-05       CHC       STL    Carlos Martinez  593372.0
# 2139668  2015-04-05       CHC       STL        Pedro Strop  467008.0
# 2139659  2015-04-05       CHC       STL        Pedro Strop  467008.0
# 2139653  2015-04-05       CHC       STL      Jordan Walden  477229.0
# 2139644  2015-04-05       CHC       STL      Jordan Walden  477229.0
# 2139640  2015-04-05       CHC       STL      Jordan Walden  477229.0
# 2139624  2015-04-05       CHC       STL      Hector Rondon  444468.0
# 2139617  2015-04-05       CHC       STL   Trevor Rosenthal  572096.0
# 2139612  2015-04-05       CHC       STL   Trevor Rosenthal  572096.0
# 2139606  2015-04-05       CHC       STL   Trevor Rosenthal  572096.0
# ...             ...       ...       ...                ...       ...
# 393      2017-10-01       LAA       SEA       James Paxton  572020.0
# 387      2017-10-01       LAA       SEA       James Paxton  572020.0
# 382      2017-10-01       LAA       SEA       James Paxton  572020.0
# 363      2017-10-01       LAA       SEA       James Paxton  572020.0
# 358      2017-10-01       LAA       SEA    Parker Bridwell  592170.0
# 342      2017-10-01       LAA       SEA       Shae Simmons  623406.0
# 324      2017-10-01       LAA       SEA       Shae Simmons  623406.0
# 313      2017-10-01       LAA       SEA        James Pazos  572021.0
# 299      2017-10-01       LAA       SEA       Jose Alvarez  501625.0
# 275      2017-10-01       LAA       SEA     Casey Lawrence  596271.0
# 263      2017-10-01       LAA       SEA         Blake Wood  502028.0
# 250      2017-10-01       NYY       TOR  Jordan Montgomery  656756.0
# 246      2017-10-01       NYY       TOR  Jordan Montgomery  656756.0
# 229      2017-10-01       NYY       TOR     Brett Anderson  474463.0
# 196      2017-10-01       NYY       TOR     Brett Anderson  474463.0
# 191      2017-10-01       NYY       TOR     Brett Anderson  474463.0
# 178      2017-10-01       NYY       TOR  Jordan Montgomery  656756.0
# 127      2017-10-01       NYY       TOR  Jordan Montgomery  656756.0
# 122      2017-10-01       NYY       TOR        Adam Warren  476589.0
# 115      2017-10-01       NYY       TOR        Luis Santos  608601.0
# 103      2017-10-01       NYY       TOR        Luis Santos  608601.0
# 91       2017-10-01       NYY       TOR     Domingo German  593334.0
# 81       2017-10-01       NYY       TOR       Danny Barnes  592130.0
# 67       2017-10-01       NYY       TOR     Domingo German  593334.0
# 60       2017-10-01       NYY       TOR     Domingo German  593334.0
# 50       2017-10-01       NYY       TOR     Domingo German  593334.0
# 44       2017-10-01       NYY       TOR        Ryan Tepera  572193.0
# 38       2017-10-01       NYY       TOR        Ryan Tepera  572193.0
# 29       2017-10-01       NYY       TOR         Ben Heller  621294.0
# 12       2017-10-01       NYY       TOR      Roberto Osuna  532077.0
#
#         pitch_type        pitch_name  pitch_velocity    batter  \
# 2139906         CU         Curveball            76.8  425509.0
# 2139901         FC            Cutter            89.9  571431.0
# 2139890         FC            Cutter            84.9  519203.0
# 2139882         FF   4-Seam Fastball            92.0  425877.0
# 2139875         FF   4-Seam Fastball            89.6  543939.0
# 2139866         FF   4-Seam Fastball            91.1  425794.0
# 2139864         FF   4-Seam Fastball            88.7  518792.0
# 2139854         CU         Curveball            77.1  592609.0
# 2139849         FF   4-Seam Fastball            90.3  452657.0
# 2139837         FF   4-Seam Fastball            92.7  425509.0
# 2139814         FC            Cutter            85.9  624585.0
# 2139808         CU         Curveball            76.8  519203.0
# 2139803         FF   4-Seam Fastball            90.0  425877.0
# 2139792         FC            Cutter            83.6  445055.0
# 2139763         FF   4-Seam Fastball            93.4  571431.0
# 2139759         IN  Intentional Ball            71.5  425877.0
# 2139755         FT   2-Seam Fastball            93.3  543939.0
# 2139737         CU         Curveball            75.4  451594.0
# 2139701         FF   4-Seam Fastball            93.3  407812.0
# 2139687         FT   2-Seam Fastball            92.9  570489.0
# 2139681         CH          Changeup            85.1  471083.0
# 2139668         FT   2-Seam Fastball            94.4  425877.0
# 2139659         SL            Slider            83.7  448602.0
# 2139653         CH          Changeup            86.5  451594.0
# 2139644         CH          Changeup            86.8  519203.0
# 2139640         SL            Slider            87.0  516770.0
# 2139624         SL            Slider            84.8  407812.0
# 2139617         FF   4-Seam Fastball            98.4  458085.0
# 2139612         FF   4-Seam Fastball            98.5  592609.0
# 2139606         FF   4-Seam Fastball            98.1  570489.0
# ...            ...               ...             ...       ...
# 393             KC     Knuckle Curve            81.2  543068.0
# 387             FC            Cutter            87.8  460060.0
# 382             KC     Knuckle Curve            80.8  592230.0
# 363             KC     Knuckle Curve            80.4  545337.0
# 358             CU         Curveball            77.1  443558.0
# 342             CU         Curveball            82.1  472528.0
# 324             FT   2-Seam Fastball            94.2  592230.0
# 313             SI            Sinker            92.5  545337.0
# 299             CU         Curveball            78.7  592325.0
# 275             SL            Slider            83.4  592230.0
# 263             FS      Split Finger            83.9  443558.0
# 250             CU         Curveball            79.6  606192.0
# 246             CU         Curveball            80.8  620446.0
# 229             FF   4-Seam Fastball            93.5  407812.0
# 196             SL            Slider            82.2  640449.0
# 191             SL            Slider            84.1  592122.0
# 178             FF   4-Seam Fastball            91.8  620446.0
# 127             SL            Slider            85.6  572365.0
# 122             FF   4-Seam Fastball            91.3  606192.0
# 115             FT   2-Seam Fastball            92.9  592122.0
# 103             CH          Changeup            84.0  591720.0
# 91              CU         Curveball            83.4  607257.0
# 81              FF   4-Seam Fastball            91.8  595885.0
# 67              CU         Curveball            81.8  608701.0
# 60              FF   4-Seam Fastball            96.7  485567.0
# 50              FF   4-Seam Fastball            97.0  606192.0
# 44              FC            Cutter            88.9  592122.0
# 38              FC            Cutter            89.5  543305.0
# 29              CU         Curveball            82.8  620446.0
# 12              FC            Cutter            91.0  642180.0
#
#                      events              description batted_ball_type  \
# 2139906           strikeout          swinging_strike              NaN
# 2139901           strikeout          swinging_strike              NaN
# 2139890           strikeout            called_strike              NaN
# 2139882           strikeout          swinging_strike              NaN
# 2139875                walk                     ball              NaN
# 2139866           strikeout            called_strike              NaN
# 2139864  caught_stealing_2b                     ball              NaN
# 2139854           strikeout  swinging_strike_blocked              NaN
# 2139849           strikeout            called_strike              NaN
# 2139837           strikeout            called_strike              NaN
# 2139814           strikeout          swinging_strike              NaN
# 2139808           strikeout                 foul_tip              NaN
# 2139803                walk                     ball              NaN
# 2139792           strikeout            called_strike              NaN
# 2139763           strikeout          swinging_strike              NaN
# 2139759         intent_walk              intent_ball              NaN
# 2139755           strikeout          swinging_strike              NaN
# 2139737           strikeout          swinging_strike              NaN
# 2139701           strikeout          swinging_strike              NaN
# 2139687                walk             blocked_ball              NaN
# 2139681           strikeout          swinging_strike              NaN
# 2139668           strikeout                 foul_tip              NaN
# 2139659           strikeout            called_strike              NaN
# 2139653           strikeout            called_strike              NaN
# 2139644                walk                     ball              NaN
# 2139640           strikeout  swinging_strike_blocked              NaN
# 2139624                walk                     ball              NaN
# 2139617           strikeout            called_strike              NaN
# 2139612           strikeout          swinging_strike              NaN
# 2139606           strikeout          swinging_strike              NaN
# ...                     ...                      ...              ...
# 393               strikeout  swinging_strike_blocked              NaN
# 387               strikeout          swinging_strike              NaN
# 382               strikeout            called_strike              NaN
# 363               strikeout          swinging_strike              NaN
# 358            hit_by_pitch             hit_by_pitch              NaN
# 342                    walk             blocked_ball              NaN
# 324                    walk                     ball              NaN
# 313                    walk                     ball              NaN
# 299               strikeout  swinging_strike_blocked              NaN
# 275               strikeout          swinging_strike              NaN
# 263               strikeout  swinging_strike_blocked              NaN
# 250               strikeout            called_strike              NaN
# 246               strikeout          swinging_strike              NaN
# 229               strikeout          swinging_strike              NaN
# 196               strikeout          swinging_strike              NaN
# 191               strikeout          swinging_strike              NaN
# 178                    walk                     ball              NaN
# 127               strikeout  swinging_strike_blocked              NaN
# 122               strikeout          swinging_strike              NaN
# 115               strikeout            called_strike              NaN
# 103               strikeout          swinging_strike              NaN
# 91                strikeout          swinging_strike              NaN
# 81                     walk                     ball              NaN
# 67                strikeout  swinging_strike_blocked              NaN
# 60                     walk                     ball              NaN
# 50                strikeout          swinging_strike              NaN
# 44                strikeout          swinging_strike              NaN
# 38                strikeout          swinging_strike              NaN
# 29                strikeout          swinging_strike              NaN
# 12                strikeout          swinging_strike              NaN
#
#                                                        des  exit_velocity  \
# 2139906               Jhonny Peralta strikes out swinging.            NaN
# 2139901                   Matt Adams strikes out swinging.            NaN
# 2139890               Anthony Rizzo called out on strikes.            NaN
# 2139882                Yadier Molina strikes out swinging.            NaN
# 2139875                                 Kolten Wong walks.            NaN
# 2139866             Adam Wainwright called out on strikes.            NaN
# 2139864  With Jason Heyward batting, Matt Carpenter cau...            NaN
# 2139854                     Mike Olt strikes out swinging.            NaN
# 2139849                  Jon Lester called out on strikes.            NaN
# 2139837              Jhonny Peralta called out on strikes.            NaN
# 2139814                  Jorge Soler strikes out swinging.            NaN
# 2139808           Anthony Rizzo strikes out on a foul tip.            NaN
# 2139803                               Yadier Molina walks.            NaN
# 2139792                     Jon Jay called out on strikes.            NaN
# 2139763                   Matt Adams strikes out swinging.            NaN
# 2139759       Phil Coke intentionally walks Yadier Molina.            NaN
# 2139755                  Kolten Wong strikes out swinging.            NaN
# 2139737                Dexter Fowler strikes out swinging.            NaN
# 2139701                Matt Holliday strikes out swinging.            NaN
# 2139687                         Arismendy Alcantara walks.            NaN
# 2139681               Miguel Montero strikes out swinging.            NaN
# 2139668           Yadier Molina strikes out on a foul tip.            NaN
# 2139659               Mark Reynolds called out on strikes.            NaN
# 2139653               Dexter Fowler called out on strikes.            NaN
# 2139644                               Anthony Rizzo walks.            NaN
# 2139640               Starlin Castro strikes out swinging.            NaN
# 2139624                               Matt Holliday walks.            NaN
# 2139617               Chris Coghlan called out on strikes.            NaN
# 2139612                     Mike Olt strikes out swinging.            NaN
# 2139606          Arismendy Alcantara strikes out swinging.            NaN
# ...                                                    ...            ...
# 393                  C.  J.   Cron strikes out swinging.              NaN
# 387               Cliff Pennington strikes out swinging.              NaN
# 382                  Kaleb Cowart called out on strikes.              NaN
# 363                  Nolan Fontana strikes out swinging.              NaN
# 358                            Nelson Cruz hit by pitch.              NaN
# 342                                 Luis Valbuena walks.              NaN
# 324                                  Kaleb Cowart walks.              NaN
# 313                                 Nolan Fontana walks.              NaN
# 299      Ben Gamel strikes out swinging, catcher Juan G...            NaN
# 275                   Kaleb Cowart strikes out swinging.              NaN
# 263                    Nelson Cruz strikes out swinging.              NaN
# 250             Teoscar Hernandez called out on strikes.              NaN
# 246                  Richard Urena strikes out swinging.              NaN
# 229                  Matt Holliday strikes out swinging.              NaN
# 196                  Clint Frazier strikes out swinging.              NaN
# 191                   Tyler Austin strikes out swinging.              NaN
# 178                                 Richard Urena walks.              NaN
# 127                     Ryan Goins strikes out swinging.              NaN
# 122              Teoscar Hernandez strikes out swinging.              NaN
# 115                  Tyler Austin called out on strikes.              NaN
# 103                Ronald Torreyes strikes out swinging.              NaN
# 91                     Raffy Lopez strikes out swinging.              NaN
# 81                                      Greg Bird walks.              NaN
# 67       Rob Refsnyder strikes out swinging.  Wild pitc...            NaN
# 60       Ezequiel Carrera walks.   Rob Refsnyder to 2nd.              NaN
# 50               Teoscar Hernandez strikes out swinging.              NaN
# 44                    Tyler Austin strikes out swinging.              NaN
# 38                     Aaron Hicks strikes out swinging.              NaN
# 29                   Richard Urena strikes out swinging.              NaN
# 12                      Tyler Wade strikes out swinging.              NaN
#
#          launch_angle  hit_distance_sc
# 2139906           NaN              NaN
# 2139901           NaN              NaN
# 2139890           NaN              NaN
# 2139882           NaN              NaN
# 2139875           NaN              NaN
# 2139866           NaN              NaN
# 2139864           NaN              NaN
# 2139854           NaN              NaN
# 2139849           NaN              NaN
# 2139837           NaN              NaN
# 2139814           NaN              NaN
# 2139808           NaN              NaN
# 2139803           NaN              NaN
# 2139792           NaN              NaN
# 2139763           NaN              NaN
# 2139759           NaN              NaN
# 2139755           NaN              NaN
# 2139737           NaN              NaN
# 2139701           NaN              NaN
# 2139687           NaN              NaN
# 2139681           NaN              NaN
# 2139668           NaN              NaN
# 2139659           NaN              NaN
# 2139653           NaN              NaN
# 2139644           NaN              NaN
# 2139640           NaN              NaN
# 2139624           NaN              NaN
# 2139617           NaN              NaN
# 2139612           NaN              NaN
# 2139606           NaN              NaN
# ...               ...              ...
# 393               NaN              NaN
# 387               NaN              NaN
# 382               NaN              NaN
# 363               NaN              NaN
# 358               NaN              NaN
# 342               NaN              NaN
# 324               NaN              NaN
# 313               NaN              NaN
# 299               NaN              NaN
# 275               NaN              NaN
# 263               NaN              NaN
# 250               NaN              NaN
# 246               NaN              NaN
# 229               NaN              NaN
# 196               NaN              NaN
# 191               NaN              NaN
# 178               NaN              NaN
# 127               NaN              NaN
# 122               NaN              NaN
# 115               NaN              NaN
# 103               NaN              NaN
# 91                NaN              NaN
# 81                NaN              NaN
# 67                NaN              NaN
# 60                NaN              NaN
# 50                NaN              NaN
# 44                NaN              NaN
# 38                NaN              NaN
# 29                NaN              NaN
# 12                NaN              NaN
#
# [166927 rows x 16 columns]

# %% [markdown]
# #### What types of `events` occurred for missing `batted_ball_type`?

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new[null_batted_ball_type].events.value_counts(dropna=False)
# Out:
# strikeout                       116120
# walk                             42138
# hit_by_pitch                      5019
# intent_walk                       1884
# caught_stealing_2b                 696
# strikeout_double_play              435
# pickoff_caught_stealing_2b         131
# other_out                          120
# catcher_interf                     113
# pickoff_1b                          95
# caught_stealing_3b                  56
# pickoff_2b                          55
# caught_stealing_home                29
# run                                 16
# pickoff_caught_stealing_3b          10
# batter_interference                  4
# pickoff_caught_stealing_home         3
# pickoff_3b                           3
# Name: events, dtype: int64

# %% [markdown]
# #### Drop missing values from `batted_ball_type` column.

# %%
# Remove missing values
# Note: axis=0 (default) drop rows which contain missing values
#       how='any' (default) drops rows if ANY missing values are present from any column -- can be dangerous!
#       subset: if you are dropping rows these would be a list of columns to include
#       inplace=True changes the original DataFrame
all_MLB_teams2015_2017_new.dropna(subset=['batted_ball_type'], inplace=True)

# %% [markdown]
# #### Confirm whether the values for `events` and `batted_ball_type` are valid (i.e., values could provide valid measurements for Statcast metrics).

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new.events.value_counts(dropna=False)
# Out:
# field_out                    223381
# single                        82491
# double                        24898
# home_run                      16629
# force_out                     11500
# grounded_into_double_play     11266
# field_error                    4816
# sac_fly                        3549
# sac_bunt                       3149
# triple                         2607
# double_play                    1348
# fielders_choice_out             919
# fielders_choice                 301
# sac_fly_double_play              66
# triple_play                      18
# sac_bunt_double_play              3
# Name: events, dtype: int64

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new.batted_ball_type.value_counts(dropna=False)
# Out:
# ground_ball    178646
# line_drive      99714
# fly_ball        81752
# popup           26829
# Name: batted_ball_type, dtype: int64

# %%
all_MLB_teams2015_2017_new.batted_ball_type.value_counts(dropna=False).sum()
# Out:
# 386941

# %%
# Compute a frequency table of two factors
# Builtin-Styles - https://pandas.pydata.org/pandas-docs/stable/style.html
orange = sns.light_palette('orange', as_cmap=True)
pd.crosstab(all_MLB_teams2015_2017_new.events, all_MLB_teams2015_2017_new.batted_ball_type, margins=True, margins_name='Total', dropna=False).style.background_gradient(cmap=orange)
# Out:
# <style  type="text/css" >
#     #T_b262d924_6ad8_11e9_8501_acde48001122row0_col0 {
#             background-color:  #fff3dc;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row0_col1 {
#             background-color:  #fff5e2;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row0_col2 {
#             background-color:  #ffe8bd;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row0_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row0_col4 {
#             background-color:  #fff1d7;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row1_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row1_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row1_col2 {
#             background-color:  #fff5e4;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row1_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row1_col4 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row2_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row2_col1 {
#             background-color:  #fff4e0;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row2_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row2_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row2_col4 {
#             background-color:  #fff5e3;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row3_col0 {
#             background-color:  #ffba3c;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row3_col1 {
#             background-color:  #ffc760;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row3_col2 {
#             background-color:  #ffdb98;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row3_col3 {
#             background-color:  #ffa807;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row3_col4 {
#             background-color:  #ffc761;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row4_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row4_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row4_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row4_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row4_col4 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row5_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row5_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row5_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row5_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row5_col4 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row6_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row6_col1 {
#             background-color:  #fff1d7;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row6_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row6_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row6_col4 {
#             background-color:  #fff4df;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row7_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row7_col1 {
#             background-color:  #fff1d7;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row7_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row7_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row7_col4 {
#             background-color:  #fff4df;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row8_col0 {
#             background-color:  #ffebc5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row8_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row8_col2 {
#             background-color:  #fff2da;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row8_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row8_col4 {
#             background-color:  #fff3dc;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row9_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row9_col1 {
#             background-color:  #fff5e2;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row9_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row9_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row9_col4 {
#             background-color:  #fff5e4;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row10_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row10_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row10_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row10_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row10_col4 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row11_col0 {
#             background-color:  #fff4df;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row11_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row11_col2 {
#             background-color:  #fff5e4;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row11_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row11_col4 {
#             background-color:  #fff5e4;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row12_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row12_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row12_col2 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row12_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row12_col4 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row13_col0 {
#             background-color:  #fff3de;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row13_col1 {
#             background-color:  #ffe4b2;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row13_col2 {
#             background-color:  #ffd68b;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row13_col3 {
#             background-color:  #fff5e2;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row13_col4 {
#             background-color:  #ffe5b5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row14_col0 {
#             background-color:  #fff5e4;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row14_col1 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row14_col2 {
#             background-color:  #fff5e2;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row14_col3 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row14_col4 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122row15_col0 {
#             background-color:  #fff6e5;
#         }    #T_b262d924_6ad8_11e9_8501_acde48001122r

# %% [markdown]
# Note: The above frequencies confirm valid values.

# %%
# Count the missing values in each column of a DataFrame - sum() works because True is 1 and False is 0
all_MLB_teams2015_2017_new.isnull().sum()
# Out:
# game_date               0
# home_team               0
# away_team               0
# player_name             0
# pitcher                 0
# pitch_type            701
# pitch_name            701
# pitch_velocity        459
# batter                  0
# events                  0
# description             0
# batted_ball_type        0
# des                     2
# exit_velocity          66
# launch_angle           66
# hit_distance_sc     46472
# dtype: int64

# %%
# Create a vertical bar plot by number of missing values per column using matplotlib
# Note: figsize: a tuple (width, height) in inches
all_MLB_teams2015_2017_new.isnull().sum().plot.bar(figsize=(10, 8));
plt.title('Number of null values per column');

# %% [markdown]
# Note: There are still missing values for the following variables: `pitch_name`, `pitch_velocity`, `exit_velocity`, `launch_angle`. These variables will be used in the modeling and observations with missing values will be dropped.

# %% [markdown]
# #### Drop missing values from `pitch_name`, `pitch_velocity`, `exit_velocity`, `launch_angle` columns.

# %%
# Remove missing values
# Note: axis=0 (default) drop rows which contain missing values
#       how='any' (default) drops rows if ANY missing values are present from any column -- can be dangerous!
#       subset: if you are dropping rows these would be a list of columns to include
#       inplace=True changes the original DataFrame
all_MLB_teams2015_2017_new.dropna(subset=['pitch_name', 'pitch_velocity', 'exit_velocity', 'launch_angle'], inplace=True)

# %% [markdown]
# ### Summarize the DataFrame

# %%
# Describe numeric columns
# Generates descriptive summary statistics of the central tendency, dispersion, and shape of the distribution
# Note: By default only numeric (int64) fields are returned
#       Excludes "NaN" (missing) values
# Remove multiple columns
# Note: axis=0 for rows, 1 for columns
all_MLB_teams2015_2017_new.drop(['pitcher', 'batter'], axis=1).describe()
# Out:
#        pitch_velocity  exit_velocity   launch_angle  hit_distance_sc
# count   386112.000000  386112.000000  386112.000000    340221.000000
# mean        88.938052      87.228387      10.662181       170.446680
# std          5.809726      14.532315      27.245971       136.700367
# min         41.500000       5.200000     -88.890000         0.000000
# 25%         85.100000      80.000000      -8.987000        22.000000
# 50%         90.300000      89.300000      10.605000       169.000000
# 75%         93.300000      98.100000      28.520775       294.000000
# max        105.400000     123.400000      89.850000       504.000000

# %%
# Describe object columns (e.g. categorical, strings, or timestamps)
# Generates descriptive summary statistics of the count, unique values, top values, and frequency
# Note: "top" is the most common value; "freq" is the most common value's frequency
#       Excludes "NaN" (missing) values
# Remove multiple columns
# Note: axis=0 for rows, 1 for columns
all_MLB_teams2015_2017_new.drop(['home_team', 'away_team', 'player_name', 'des'], axis=1).describe(include='object')
# Out:
#          game_date pitch_type       pitch_name     events    description  \
# count       386112     386112           386112     386112         386112
# unique         537         16               16         16              4
# top     2015-09-30         FF  4-Seam Fastball  field_out  hit_into_play
# freq           974     131254           131254     222928         249245
#
#        batted_ball_type
# count            386112
# unique                4
# top         ground_ball
# freq             178259

# %%
# Compute a frequency table of two factors
# Builtin-Styles - https://pandas.pydata.org/pandas-docs/stable/style.html
orange = sns.light_palette('orange', as_cmap=True)
pd.crosstab(all_MLB_teams2015_2017_new.pitch_name, all_MLB_teams2015_2017_new.pitch_type, margins=True, margins_name='Total').style.background_gradient(cmap=orange)
# Out:
# <style  type="text/css" >
#     #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col0 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col1 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col2 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col3 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col4 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col5 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col6 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col7 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col8 {
#             background-color:  #ffa500;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col9 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col10 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col11 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col12 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col13 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col14 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col15 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row0_col16 {
#             background-color:  #ffeac2;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col0 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col1 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col2 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col3 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col4 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col5 {
#             background-color:  #ffa500;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col6 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col7 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col8 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col9 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col10 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col11 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col12 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col13 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col14 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col15 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row1_col16 {
#             background-color:  #ffda97;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col0 {
#             background-color:  #ffa500;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col1 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col2 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col3 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col4 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col5 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col6 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col7 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col8 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col9 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col10 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col11 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col12 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col13 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col14 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col15 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row2_col16 {
#             background-color:  #ffedcb;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col0 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col1 {
#             background-color:  #ffa500;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col2 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col3 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col4 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col5 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col6 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col7 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col8 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col9 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col10 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col11 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col12 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col13 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col14 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col15 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row3_col16 {
#             background-color:  #fff1d6;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col0 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col1 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col2 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col3 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col4 {
#             background-color:  #ffa500;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col5 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col6 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde48001122row4_col7 {
#             background-color:  #fff6e5;
#         }    #T_b334c1fa_6ad8_11e9_b54a_acde4800112

# %% [markdown]
# #### Drop low frequency `pitch_name` observations

# %%
# Return elements, either from `x` or `y`, depending on `condition`
all_MLB_teams2015_2017_new['pitch_name_low_freq'] = np.where(all_MLB_teams2015_2017_new.pitch_name.isin(['Eephus', 'Fastball', 'Forkball', 'Pitch Out', 'Screwball', 'Unknown']), 1, 0)

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new.pitch_name_low_freq.value_counts(dropna=False)
# Out:
# 0    385848
# 1       264
# Name: pitch_name_low_freq, dtype: int64

# %%
# Excluding low frequency values
all_MLB_teams2015_2017_new = all_MLB_teams2015_2017_new[all_MLB_teams2015_2017_new.pitch_name_low_freq == 0]
all_MLB_teams2015_2017_new.drop('pitch_name_low_freq', axis=1, inplace=True)

# %%
# Return the number of rows and columns (dimensionality) of the DataFrame
print('Rows: {}, Cols: {}'.format(all_MLB_teams2015_2017_new.shape[0], all_MLB_teams2015_2017_new.shape[1]))
# Out:
# Rows: 385848, Cols: 16

# %% [markdown]
# #### Create indicator for whether an event was a Home Run (HR).

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
all_MLB_teams2015_2017_new.events.value_counts(dropna=False)
# Out:
# field_out                    222774
# single                        82232
# double                        24838
# home_run                      16587
# force_out                     11474
# grounded_into_double_play     11234
# field_error                    4806
# sac_fly                        3539
# sac_bunt                       3117
# triple                         2599
# double_play                    1345
# fielders_choice_out             916
# fielders_choice                 300
# sac_fly_double_play              66
# triple_play                      18
# sac_bunt_double_play              3
# Name: events, dtype: int64

# %%
# Lambda function: apply an arbitrary function to each value of a Pandas column, storing the result in a new column
all_MLB_teams2015_2017_new['hr'] = all_MLB_teams2015_2017_new.events.apply(lambda events: 1 if events == 'home_run' else 0)

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
print(all_MLB_teams2015_2017_new.hr.value_counts(dropna=False))
round(all_MLB_teams2015_2017_new.hr.value_counts(dropna=False) / len(all_MLB_teams2015_2017_new), 3)
# Out:
# 0    369261
# 1     16587
# Name: hr, dtype: int64
# 0    0.957
# 1    0.043
# Name: hr, dtype: float64

# %% [markdown]
# #### Create indicator for whether an event was an Extra-base Hit (XBH).

# %%
# Check whether `values` are contained in Series
#all_MLB_teams2015_2017_new['xbh_bool'] = all_MLB_teams2015_2017_new.events.isin(['double', 'triple', 'home_run'])

# %%
# Map values of Series using input correspondence (i.e., map existing input values to new outputs values)
#all_MLB_teams2015_2017_new['xbh'] = all_MLB_teams2015_2017_new.xbh_bool.map({False:0, True:1})
#all_MLB_teams2015_2017_new.drop('xbh_bool', axis=1, inplace=True)

# %%
# Return elements, either from `x` or `y`, depending on `condition`
all_MLB_teams2015_2017_new['xbh'] = np.where(all_MLB_teams2015_2017_new.events.isin(['double', 'triple', 'home_run']), 1, 0)

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
print(all_MLB_teams2015_2017_new.xbh.value_counts(dropna=False))
round(all_MLB_teams2015_2017_new.xbh.value_counts(dropna=False) / len(all_MLB_teams2015_2017_new), 3)
# Out:
# 0    341824
# 1     44024
# Name: xbh, dtype: int64
# 0    0.886
# 1    0.114
# Name: xbh, dtype: float64

# %%
# Calculate the correlation matrix using the default method (Pearson correlation)
baseball_correlations = all_MLB_teams2015_2017_new.drop(['pitcher', 'batter'], axis=1).corr(method='pearson')
baseball_correlations
# Out:
#                  pitch_velocity  exit_velocity  launch_angle  hit_distance_sc  \
# pitch_velocity         1.000000       0.078758      0.006906         0.016692
# exit_velocity          0.078758       1.000000      0.186630         0.352101
# launch_angle           0.006906       0.186630      1.000000         0.732524
# hit_distance_sc        0.016692       0.352101      0.732524         1.000000
# hr                    -0.006979       0.233394      0.134847         0.375045
# xbh                   -0.003404       0.302958      0.134149         0.416674
#
#                        hr       xbh
# pitch_velocity  -0.006979 -0.003404
# exit_velocity    0.233394  0.302958
# launch_angle     0.134847  0.134149
# hit_distance_sc  0.375045  0.416674
# hr               1.000000  0.590573
# xbh              0.590573  1.000000

# %%
# Create a figure and a set of subplots
# Note: figsize: a tuple (width, height) in inches
fig, ax = plt.subplots(figsize=(10, 8));

# Return an array of zeros with the same shape and type as a given array
mask = np.zeros_like(baseball_correlations, dtype=np.bool)
# Return the indices for the upper-triangle of array
mask[np.triu_indices_from(mask)] = True

# Plot the correlation matrix (color-encoded) using Seaborn's .heatmap() function
# Note: vmin, vmax: values to anchor the colormap, otherwise they are inferred from the data & other keyword arguments
ax = sns.heatmap(baseball_correlations, vmin=-1, vmax=1, mask=mask, ax=ax);

ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14);
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14);

plt.show();

# %%
# For each HR group, describe exit velocity:
all_MLB_teams2015_2017_new.groupby(by='hr').exit_velocity.describe()
# Out:
#        count        mean        std   min    25%    50%    75%    max
# hr
# 0   369261.0   86.511807  14.414668   5.2   80.0   88.6   97.1  123.4
# 1    16587.0  103.234033   4.414319  36.6  100.5  103.3  106.2  121.1

# %%
# Create histograms
# Note: column: used to limit data to a subset of columns
#       by: used to form histograms for separate groups
#       sharex: share x axis and set some x axis labels to invisible
#       sharey: share y axis and set some y axis labels to invisible
#       layout: tuple of (rows, columns) for the layout of the histograms
#       figsize: a tuple (width, height) in inches
all_MLB_teams2015_2017_new.hist(column='exit_velocity', by='hr', sharex=True, sharey=True, figsize=(10, 8));
plt.xlabel('Exit Velocity (MPH)');
plt.ylabel('Frequency');

# %%
# For each HR group, describe launch angle:
all_MLB_teams2015_2017_new.groupby(by='hr').launch_angle.describe()
# Out:
#        count       mean        std     min     25%     50%      75%     max
# hr
# 0   369261.0   9.883912  27.574537 -88.890 -10.133   9.102  27.6080  89.850
# 1    16587.0  27.997869   5.258122 -47.842  24.156  27.650  31.3585  49.741

# %%
# Create histograms
# Note: column: used to limit data to a subset of columns
#       by: used to form histograms for separate groups
#       sharex: share x axis and set some x axis labels to invisible
#       sharey: share y axis and set some y axis labels to invisible
#       layout: tuple of (rows, columns) for the layout of the histograms
#       figsize: a tuple (width, height) in inches
all_MLB_teams2015_2017_new.hist(column='launch_angle', by='hr', sharex=True, sharey=True, figsize=(10, 8));
plt.xlabel('Launch Angle (Degrees)');
plt.ylabel('Frequency');

# %%
# For each XBH group, describe exit velocity:
all_MLB_teams2015_2017_new.groupby(by='xbh').exit_velocity.describe()
# Out:
#         count       mean        std   min   25%    50%    75%    max
# xbh
# 0    341824.0  85.650642  14.394967   5.2  79.5   87.4   96.0  123.4
# 1     44024.0  99.498778   8.496135  32.2  96.5  101.2  104.8  121.1

# %%
# Create histograms
# Note: column: used to limit data to a subset of columns
#       by: used to form histograms for separate groups
#       sharex: share x axis and set some x axis labels to invisible
#       sharey: share y axis and set some y axis labels to invisible
#       layout: tuple of (rows, columns) for the layout of the histograms
#       figsize: a tuple (width, height) in inches
all_MLB_teams2015_2017_new.hist(column='exit_velocity', by='xbh', sharex=True, sharey=True, figsize=(10, 8));
plt.xlabel('Exit Velocity (MPH)');
plt.ylabel('Frequency');

# %%
# For each XBH group, describe launch angle:
all_MLB_teams2015_2017_new.groupby(by='xbh').launch_angle.describe()
# Out:
#         count       mean        std     min      25%     50%       75%    max
# xbh
# 0    341824.0   9.350901  28.432802 -88.890 -11.9267   7.282  28.96625  89.85
# 1     44024.0  20.847295  10.596456 -62.942  15.5800  21.752  27.62325  69.72

# %%
# Create histograms
# Note: column: used to limit data to a subset of columns
#       by: used to form histograms for separate groups
#       sharex: share x axis and set some x axis labels to invisible
#       sharey: share y axis and set some y axis labels to invisible
#       layout: tuple of (rows, columns) for the layout of the histograms
#       figsize: a tuple (width, height) in inches
all_MLB_teams2015_2017_new.hist(column='launch_angle', by='xbh', sharex=True, sharey=True, figsize=(10, 8));
plt.xlabel('Launch Angle (Degrees)');
plt.ylabel('Frequency');

# %% [markdown]
# ### Data Modeling

# %% [markdown]
# ### Using Logistic Regression for Classification
#
# Logistic regression: Log odds of a categorical response being "true" (1) is modeled as a linear combination of the features.
#
# $$\log \left({p\over 1-p}\right) = \beta_0 + \beta_1x$$
#
# This is called the logit function.
#
# The equation can be rearranged into the logistic function.
#
# $$\hat{p} = \frac{e^{\beta_0 + \beta_1x}} {1 + e^{\beta_0 + \beta_1x}}$$

# %% [markdown]
# #### Build and train logistic regression models

# %% [markdown]
# Create dummy variables for `pitch_name`.

# %%
# Convert categorical variable into dummy/indicator variables
# Note: prefix: string to append DataFrame column names
#       drop_first=True removes the first level to get k-1 dummies out of k categorical events
# Join columns with other DataFrame either on index or on a key
all_MLB_teams2015_2017_new = all_MLB_teams2015_2017_new.join(pd.get_dummies(all_MLB_teams2015_2017_new.pitch_name, prefix='pitch_name', drop_first=True))
all_MLB_teams2015_2017_new.head()
# Out:
#           game_date home_team away_team      player_name   pitcher pitch_type  \
# 2139914  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139912  2015-04-05       CHC       STL       Jon Lester  452657.0         FC
# 2139909  2015-04-05       CHC       STL       Jon Lester  452657.0         FF
# 2139899  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FC
# 2139895  2015-04-05       CHC       STL  Adam Wainwright  425794.0         FC
#
#               pitch_name  pitch_velocity    batter     events  \
# 2139914  4-Seam Fastball            93.6  572761.0  field_out
# 2139912           Cutter            89.9  518792.0     double
# 2139909  4-Seam Fastball            93.2  407812.0     single
# 2139899           Cutter            88.1  451594.0     double
# 2139895           Cutter            89.9  624585.0  field_out
#
#                   ...            xbh pitch_name_4-Seam Fastball  \
# 2139914           ...              0                          1
# 2139912           ...              1                          0
# 2139909           ...              0                          1
# 2139899           ...              1                          0
# 2139895           ...              0                          0
#
#         pitch_name_Changeup  pitch_name_Curveball  pitch_name_Cutter  \
# 2139914                   0                     0                  0
# 2139912                   0                     0                  1
# 2139909                   0                     0                  0
# 2139899                   0                     0                  1
# 2139895                   0                     0                  1
#
#          pitch_name_Knuckle Ball  pitch_name_Knuckle Curve  pitch_name_Sinker  \
# 2139914                        0                         0                  0
# 2139912                        0                         0                  0
# 2139909                        0                         0                  0
# 2139899                        0                         0                  0
# 2139895                        0                         0                  0
#
#          pitch_name_Slider  pitch_name_Split Finger
# 2139914                  0                        0
# 2139912                  0                        0
# 2139909                  0                        0
# 2139899                  0                        0
# 2139895                  0                        0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Building Phase

# %% [markdown]
# #### Predicting HRs

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
print(all_MLB_teams2015_2017_new.hr.value_counts(dropna=False))
print()
print('Percentage of HR=No(0), HR=Yes(1)')
round(all_MLB_teams2015_2017_new.hr.value_counts(dropna=False)/len(all_MLB_teams2015_2017_new), 3)
# Out:
# 0    369261
# 1     16587
# Name: hr, dtype: int64
#
# Percentage of HR=No(0), HR=Yes(1)
# 0    0.957
# 1    0.043
# Name: hr, dtype: float64

# %% [markdown]
# Note: CLASSES ARE HIGHLY IMBALANCED!!

# %% [markdown]
# #### Over-sampling using Synthetic Minority Over-Sampling Technique (SMOTE)
# - Works by creating synthetic samples from the minor class (HR=Yes) instead of creating copies.
# - Randomly choosing one of the k-nearest-neighbors and using it to create a similar, but randomly tweaked, new observations.

# %%
# Create a list of features
feature_cols = ['pitch_name_4-Seam Fastball', 'pitch_name_Changeup', 'pitch_name_Curveball', 'pitch_name_Cutter',
                'pitch_name_Knuckle Ball', 'pitch_name_Knuckle Curve', 'pitch_name_Sinker', 'pitch_name_Slider', 'pitch_name_Split Finger',
                'pitch_velocity', 'exit_velocity', 'launch_angle']

# %%
# Create X and y
X = all_MLB_teams2015_2017_new[feature_cols]
y = all_MLB_teams2015_2017_new.hr

# %%
# Split X and y into training and testing sets
# Note: train_size: between 0.0 and 1.0 and represent the proportion of the dataset to include in the train split
#       test_size: between 0.0 and 1.0 and represent the proportion of the dataset to include in the test split
#       random_state: the seed used by the random number generator
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.70, test_size=0.30, random_state=65)

# %% [markdown]
# #### Compute Baseline Accuracy
# https://machinelearningmastery.com/how-to-get-baseline-results-and-why-they-matter/

# %%
# Categorical column frequency
# Returns counts of unique values in descending order (first element is the most frequently-occurring element)
# Note: Excludes NA values by default
print(y_train.value_counts())
print()

most_freq_class = y_train.value_counts().index[0]
print('Most frequent class in training dataset:', most_freq_class)
print()

print('Baseline accuracy:', round(y_test.value_counts()[most_freq_class] / y_test.count(), 3))
# Out:
# 0    258469
# 1     11624
# Name: hr, dtype: int64
#
# Most frequent class in training dataset: 0
#
# Baseline accuracy: 0.957

# %%
print('Length of X_train: {}'.format(len(X_train)))
print('Length of y_train: {}'.format(len(y_train)))
print('Length of X_test: {}'.format(len(X_test)))
print('Length of y_test: {}'.format(len(y_test)))
# Out:
# Length of X_train: 270093
# Length of y_train: 270093
# Length of X_test: 115755
# Length of y_test: 115755

# %%
print('Before over-sampling, counts of label "0": {}'.format(sum(y_train==0)))
print('Before over-sampling, counts of label "1": {}'.format(sum(y_train==1)))
# Out:
# Before over-sampling, counts of label "0": 258469
# Before over-sampling, counts of label "1": 11624

# %%
# Class to perform over-sampling using SMOTE
# -> Implementation of SMOTE and the variants Borderline SMOTE 1, 2 and SVM-SMOTE
# Note: random_state: the seed used by the random number generator
#       kind: type of SMOTE algorithm to use: 'regular', 'borderline1', 'borderline2', 'svm'
sm = SMOTE(random_state=42, kind='regular')

# %% [markdown]
# Note: Over-sampling only on the training data. By over-sampling on the training data only, none of the information in the test data is being used to create synthetic observations. Therefore, no information will bleed from test data into the model training.

# %%
# Fit the statistics and resample the data directly
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)

# %%
print('After over-sampling, the length of X_train_res: {}'.format(len(X_train_res)))
print('After over-sampling, the length of y_train_res: {} \n'.format(len(y_train_res)))

print('After over-sampling, counts of label "0": {}'.format(sum(y_train_res==0)))
print('After over-sampling, counts of label "1": {}'.format(sum(y_train_res==1)))
# Out:
# After over-sampling, the length of X_train_res: 516938
# After over-sampling, the length of y_train_res: 516938
#
# After over-sampling, counts of label "0": 258469
# After over-sampling, counts of label "1": 258469

# %%
print('Proportion of label "0" in over-sampled data', sum(y_train_res==0)/len(X_train_res))
print('Proportion of label "1" in over-sampled data', sum(y_train_res==1)/len(X_train_res))
# Out:
# Proportion of label "0" in over-sampled data 0.5
# Proportion of label "1" in over-sampled data 0.5

# %% [markdown]
# Note: CLASSES ARE PERFECTLY BALANCED!!

# %%
# Instantiate a Logistic Regression classifier and fit logistic model
# Note: random_state: the seed used by the random number generator
logreg = LogisticRegression(random_state=46)
logreg.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=46, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Predict the class labels using the logistic model
y_pred_class = logreg.predict(X_test)

# %%
# Calculate predicted probability estimates of class membership
# Each row sums to one and contains the probabilities of the point being a 0-Window glass, 1-Household glass
logreg.predict_proba(X_test)[0:10]
# Out:
# array([[9.99880799e-01, 1.19200968e-04],
#        [9.99999892e-01, 1.08045585e-07],
#        [9.98515800e-01, 1.48420043e-03],
#        [7.00834237e-01, 2.99165763e-01],
#        [9.99996433e-01, 3.56667008e-06],
#        [9.99993552e-01, 6.44805894e-06],
#        [9.98816373e-01, 1.18362729e-03],
#        [9.99999847e-01, 1.52542818e-07],
#        [2.10264788e-01, 7.89735212e-01],
#        [9.95715166e-01, 4.28483390e-03]])

# %%
# Calculate predicted probability estimates
y_pred_prob = logreg.predict_proba(X_test)[:, 1]

# %% [markdown]
# #### Get the coefficient for each feature

# %%
name = X.columns
coef = np.round(logreg.coef_[0], 4)
pd.DataFrame([name, coef], index=['Name', 'Coefficient']).transpose()
# Out:
#                           Name Coefficient
# 0   pitch_name_4-Seam Fastball      0.1557
# 1          pitch_name_Changeup     -0.0139
# 2         pitch_name_Curveball      -0.238
# 3            pitch_name_Cutter     -0.1103
# 4      pitch_name_Knuckle Ball     -0.9075
# 5     pitch_name_Knuckle Curve     -0.6822
# 6            pitch_name_Sinker     -0.2966
# 7            pitch_name_Slider      0.0973
# 8      pitch_name_Split Finger     -0.0915
# 9               pitch_velocity     -0.0633
# 10               exit_velocity      0.3887
# 11                launch_angle      0.1319

# %% [markdown]
# ### Operational Phase

# %%
# Function to make predictions 
def prediction(X_test, logreg_object): 
  
    # Predict the class labels using the logistic model
    y_pred_class = logreg_object.predict(X_test)

    print('Predicted values:')
    print(y_pred_class)
    print('')
    return y_pred_class

# %%
# Function to calculate accuracy
def cal_accuracy(y_test, y_pred_class, logreg_object):
      
    # Training accuracy classification score
    print('Training accuracy score:', round(metrics.accuracy_score(y_train_res, logreg_object.predict(X_train_res)), 3))
    
    # Testing accuracy classification score
    print('Testing accuracy score:', round(metrics.accuracy_score(y_test, y_pred_class), 3))
    
    if metrics.accuracy_score(y_train_res, logreg_object.predict(X_train_res)) < metrics.accuracy_score(y_test, y_pred_class):
        print('Testing accuracy > Training accuracy')
        print('-> Not overfitting')
    else:
        print('Testing accuracy < Training accuracy')
        print('-> Overfitting!')
    print('')
    
    # Confusion matrix to evaluate the accuracy of a classification
    print('Confusion Matrix:')
    conmat = metrics.confusion_matrix(y_test, y_pred_class)
    print(pd.DataFrame(conmat,
                       index=['True No HR', 'True HR'],
                       columns=['Predicted No HR', 'Predicted HR']))
    print('')
    
    # Build a text report showing the main classification metrics
    print('Classification Report:')
    print(metrics.classification_report(y_test, y_pred_class))
    print('')
    
    # Area Under the Receiver Operating Characteristic Curve (ROC AUC)
    print('ROC AUC:', round(metrics.roc_auc_score(y_test, y_pred_class), 3))
    print('')
    
    # Log loss, aka logistic loss or cross-entropy loss
    print('Log loss:', round(metrics.log_loss(y_test, y_pred_class), 3))

# %% [markdown]
# [Classification Accuracy is Not Enough: More Performance Measures You Can Use](https://machinelearningmastery.com/classification-accuracy-is-not-enough-more-performance-measures-you-can-use/)

# %% [markdown]
# $$Precision = Positive Predictive Value (PPV) = \frac{True Positives}{True Positives + False Positives}--> completeness$$
# - "How many of the items selected are relevant"
# - Of the items placed into a class, how many of them are True Positives.
# - The ability of the classifier to not label a sample as positive if it is negative.
# <br>
# <br>
# $$Recall = True Positive Rate(Sensitivity) = \frac{True Positives}{True Positives + False Negatives}-->exactness$$
# - "How many of the relevant items are selected"
# - Of the items that were suppose to be placed into a class, how many did we accurately place.
# - The ability of the classifier to find all the positive samples.
# <br>
# <br>
# $$F1Score = 2*\frac{precision * recall}{precision + recall}$$
# - 0 <= F1 <= 1, where 0 is awful and 1 is perfection.
# - F1 is considered a harmonic mean as it averages Precision and Recall.
# - With classification models you often times have to choose what kind of error you are willing to increase in order to reduce the other and thus you may want to optimize Precision or Recall accordingly.
# - If you are uncertain which you should optimize, F1 score may be the metric of choice.

# %% [markdown]
# #### Prediction using logistic regression

# %%
print('Results Using Logistic Regression:')
y_pred_logreg = prediction(X_test, logreg)
cal_accuracy(y_test, y_pred_logreg, logreg)
# Out:
# Results Using Logistic Regression:
# Predicted values:
# [0 0 0 ... 0 0 0]
#
# Training accuracy score: 0.897
# Testing accuracy score: 0.868
# Testing accuracy < Training accuracy
# -> Overfitting!
#
# Confusion Matrix:
#             Predicted No HR  Predicted HR
# True No HR            95828         14964
# True HR                 354          4609
#
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       1.00      0.86      0.93    110792
#           1       0.24      0.93      0.38      4963
#
# avg / total       0.96      0.87      0.90    115755
#
#
# ROC AUC: 0.897
#
# Log loss: 4.571

# %% [markdown]
# #### Use Regularization to optimize model

# %%
parameters = {'penalty': ('l1', 'l2'), 'C': [0.01, 0.1, 1.0, 10, 100]}

# %%
# Instantiate a Logistic Regression classifier
# Note: penalty: used to specify the norm used in the penalization; l1 penalty with SAGA solver (allowing 'multinomial' + L1)
#       C: inverse of regularization strength (default: 1.0); must be a positive float; like in support vector machines, smaller values specify stronger regularization
#       random_state: the seed used by the random number generator
logreg = LogisticRegression(random_state=46)

# %%
# Instantiate an exhaustive search over specified parameter values for an estimator and run fit with all sets of parameters
# Note: estimator: estimator object
#       param_grid: dictionary with parameters names (string) as keys and lists of parameter settings to try as values; 
#                   this enables searching over any sequence of parameter settings
#       cv: number of folds in k-fold cross-validation
#       return_train_score: if False, the cv_results_ attribute will not include training scores
clf = GridSearchCV(estimator=logreg, param_grid=parameters, cv=10, return_train_score=True)
clf.fit(X_train_res, y_train_res)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=46, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ('l1', 'l2'), 'C': [0.01, 0.1, 1.0, 10, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
results = pd.DataFrame.from_dict(clf.cv_results_)
pd.DataFrame.from_dict(clf.cv_results_, orient='index')
# Out:
#                                                0  \
# mean_fit_time                            20.2615
# std_fit_time                             3.44204
# mean_score_time                       0.00739863
# std_score_time                       0.000261883
# param_C                                     0.01
# param_penalty                                 l1
# params              {'C': 0.01, 'penalty': 'l1'}
# split0_test_score                       0.895056
# split1_test_score                       0.895617
# split2_test_score                       0.896545
# split3_test_score                       0.897744
# split4_test_score                       0.897802
# split5_test_score                       0.896003
# split6_test_score                       0.897241
# split7_test_score                       0.896758
# split8_test_score                       0.895694
# split9_test_score                       0.894703
# mean_test_score                         0.896316
# std_test_score                        0.00102557
# rank_test_score                                8
# split0_train_score                       0.89665
# split1_train_score                      0.896254
# split2_train_score                      0.896409
# split3_train_score                       0.89636
# split4_train_score                      0.896082
# split5_train_score                      0.896196
# split6_train_score                      0.896121
# split7_train_score                      0.896149
# split8_train_score                      0.896196
# split9_train_score                      0.896435
# mean_train_score                        0.896285
# std_train_score                      0.000167261
#
#                                                1                            2  \
# mean_fit_time                            1.34342                      29.1352
# std_fit_time                            0.123182                      5.26299
# mean_score_time                       0.00592647                   0.00817454
# std_score_time                        0.00106633                   0.00176956
# param_C                                     0.01                          0.1
# param_penalty                                 l2                           l1
# params              {'C': 0.01, 'penalty': 'l2'}  {'C': 0.1, 'penalty': 'l1'}
# split0_test_score                       0.884571                     0.895152
# split1_test_score                       0.886196                     0.895752
# split2_test_score                       0.886525                     0.896951
# split3_test_score                       0.888517                     0.898383
# split4_test_score                       0.888382                     0.898421
# split5_test_score                       0.886138                      0.89641
# split6_test_score                       0.887008                     0.897667
# split7_test_score                       0.886834                     0.896738
# split8_test_score                       0.886931                     0.896119
# split9_test_score                       0.885766                      0.89449
# mean_test_score                         0.886687                     0.896608
# std_test_score                        0.00110914                    0.0012373
# rank_test_score                               10                            7
# split0_train_score                      0.886937                     0.896895
# split1_train_score                      0.886849                     0.896706
# split2_train_score                      0.886745                     0.896691
# split3_train_score                      0.886531                     0.896573
# split4_train_score                       0.88655                     0.896633
# split5_train_score                      0.886756                     0.896459
# split6_train_score                      0.886659                     0.896702
# split7_train_score                      0.886694                     0.896373
# split8_train_score                      0.886642                     0.896497
# split9_train_score                      0.886847                     0.896547
# mean_train_score                        0.886721                     0.896607
# std_train_score                      0.000125233                  0.000142485
#
#                                               3                            4  \
# mean_fit_time                           1.78498                      30.4217
# std_fit_time                           0.110183                      2.49465
# mean_score_time                      0.00537744                   0.00868289
# std_score_time                      0.000326435                   0.00349207
# param_C                                     0.1                            1
# param_penalty                                l2                           l1
# params              {'C': 0.1, 'penalty': 'l2'}  {'C': 1.0, 'penalty': 'l1'}
# split0_test_score                      0.894649                     0.895152
# split1_test_score                      0.895307                     0.895655
# split2_test_score                        0.8961                     0.896932
# split3_test_score                      0.897416                     0.898421
# split4_test_score                      0.897841                     0.898305
# split5_test_score                       0.89581                     0.896893
# split6_test_score                      0.897183                     0.897493
# split7_test_score                        0.8961                     0.896816
# split8_test_score                      0.895636                     0.896448
# split9_test_score                      0.894548                     0.894723
# mean_test_score                        0.896059                     0.896684
# std_test_score                       0.00106581                   0.00117184
# rank_test_score                               9                            4
# split0_train_score                     0.896229                     0.896865
# split1_train_score                     0.896149                     0.896691
# split2_train_score                     0.896067                     0.896665
# split3_train_score                     0.895984                      0.89653
# split4_train_score                     0.895979                     0.896534
# split5_train_score                      0.89611                     0.896598
# split6_train_score                     0.896014                     0.896583
# split7_train_score                     0.896024                     0.896641
# split8_train_score                     0.896074                     0.896648
# split9_train_score                     0.896298                     0.896943
# mean_train_score                       0.896093                      0.89667
# std_train_score                      0.00010036                  0.000128458
#
#                                               5                           6  \
# mean_fit_time                           1.86196                     30.8871
# std_fit_time                           0.120145                     1.76112
# mean_score_time                      0.00531571                  0.00804267
# std_score_time                      0.000436392                  0.00157159
# param_C                                       1                          10
# param_penalty                                l2                          l1
# params              {'C': 1.0, 'penalty': 'l2'}  {'C': 10, 'penalty': 'l1'}
# split0_test_score                      0.895636                    0.895152
# split1_test_score                      0.896352                    0.895636
# split2_test_score                      0.897396                    0.896951
# split3_test_score                       0.89848                    0.898402
# split4_test_score                       0.89877                    0.898305
# split5_test_score                      0.897532                    0.896893
# split6_test_score                      0.898189                    0.897435
# split7_test_score                      0.896893                    0.896777
# split8_test_score                      0.896603                    0.896448
# split9_test_score                      0.894432                    0.894684
# mean_test_score                        0.897028                    0.896668
# std_test_score                       0.00127316                  0.00117333
# rank_test_score                               1                           5
# split0_train_score                     0.897224                    0.896854
# split1_train_score                     0.897026                    0.896686
# split2_train_score                     0.897084                    0.896665
# split3_train_score                     0.896856                    0.896532
# split4_train_score                     0.896923                     0.89653
# split5_train_score                     0.897011                    0.896585
# split6_train_score                     0.896981                    0.896585
# split7_train_score                     0.897099                    0.896624
# split8_train_score                     0.897088                    0.896643
# split9_train_score                     0.897366                    0.896938
# mean_train_score                       0.897066                    0.896664
# std_train_score                     0.000139005                 0.000127227
#
#                                              7                            8  \
# mean_fit_time                           2.2082                      33.5571
# std_fit_time                          0.422595                      2.20215
# mean_score_time                     0.00595858                   0.00789289
# std_score_time                      0.00164804                  0.000612637
# param_C                                     10                          100
# param_penalty                               l2                           l1
# params              {'C': 10, 'penalty': 'l2'}  {'C': 100, 'penalty': 'l1'}
# split0_test_score                     0.895249                     0.895152
# split1_test_score                     0.896042                     0.895636
# split2_test_score                     0.897261                     0.896951
# split3_test_score                     0.898344                     0.898402
# split4_test_score                     0.898712                     0.898305
# split5_test_score                     0.897338                     0.896893
# split6_test_score                     0.898035                     0.897435
# split7_test_score                     0.896913                     0.896777
# split8_test_score                     0.896506                     0.896448
# split9_test_score                     0.894529                     0.894684
# mean_test_score                       0.896893                     0.896668
# std_test_score                      0.00127336                   0.00117333
# rank_test_score                              3                            5
# split0_train_score                       0.897                     0.896856
# split1_train_score                    0.896912                     0.896682
# split2_train_score                    0.896861                     0.896665
# split3_train_score                    0.896828                      0.89653
# split4_train_score                    0.896749                     0.896532
# split5_train_score                    0.896889                     0.896585
# split6_train_score                    0.896852                     0.896588
# split7_train_score                    0.896813                     0.896624
# split8_train_score                    0.896886                     0.896643
# split9_train_score                    0.897179                     0.896938
# mean_train_score                      0.896897                     0.896664
# std_train_score                    0.000113012                  0.000127351
#
#                                               9
# mean_fit_time                           2.23588
# std_fit_time                           0.281724
# mean_score_time                      0.00658371
# std_score_time                       0.00129249
# param_C                                     100
# param_penalty                                l2
# params              {'C': 100, 'penalty': 'l2'}
# split0_test_score                      0.895423
# split1_test_score                      0.896023
# split2_test_score                       0.89728
# split3_test_score                      0.898344
# split4_test_score                      0.898692
# split5_test_score                      0.897512
# split6_test_score                      0.897938
# split7_test_score                      0.896913
# split8_test_score                      0.896545
# split9_test_score                      0.894626
# mean_test_score                         0.89693
# std_test_score                       0.00123021
# rank_test_score                               2
# split0_train_score                     0.897086
# split1_train_score                     0.896942
# split2_train_score                     0.896871
# split3_train_score                      0.89676
# split4_train_score                     0.896772
# split5_train_score                     0.896966
# split6_train_score                     0.896787
# split7_train_score                      0.89683
# split8_train_score                     0.896981
# split9_train_score                     0.897192
# mean_train_score                       0.896919
# std_train_score                     0.000135425

# %%
# Create a vertical bar plot by mean test score using matplotlib
# Note: figsize: a tuple (width, height) in inches
ax = results.plot.bar(y='mean_test_score', x='params', figsize=(10, 8));
ax.set_xticklabels(results.params, rotation=45, horizontalalignment='right');
plt.xlabel('Parameters');
plt.ylabel('Mean Test Score');
plt.title('Mean Test Score by Parameters');

# %%
print('Best parameter setting found by grid search:')
print(clf.best_params_)
print()
print('Best mean cross-validated score found by grid search:')
print(round(clf.best_score_, 3))
# Out:
# Best parameter setting found by grid search:
# {'C': 1.0, 'penalty': 'l2'}
#
# Best mean cross-validated score found by grid search:
# 0.897

# %% [markdown]
# #### Prediction using logistic regression, regularization, and cross-validation

# %%
print('Results Using Logistic Regression, Regularization, and Cross-Validation:')
y_pred_clf = prediction(X_test, clf)
cal_accuracy(y_test, y_pred_clf, clf)
# Out:
# Results Using Logistic Regression, Regularization, and Cross-Validation:
# Predicted values:
# [0 0 0 ... 0 0 0]
#
# Training accuracy score: 0.897
# Testing accuracy score: 0.868
# Testing accuracy < Training accuracy
# -> Overfitting!
#
# Confusion Matrix:
#             Predicted No HR  Predicted HR
# True No HR            95828         14964
# True HR                 354          4609
#
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       1.00      0.86      0.93    110792
#           1       0.24      0.93      0.38      4963
#
# avg / total       0.96      0.87      0.90    115755
#
#
# ROC AUC: 0.897
#
# Log loss: 4.571

# %% [markdown]
# #### Plot Receiver Operating Characteristic (ROC) Curve

# %%
roc_auc = metrics.roc_auc_score(y_test, clf.predict(X_test))
fpr, tpr, thresholds = metrics.roc_curve(y_test, clf.predict_proba(X_test)[:, 1])

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.3f' % roc_auc)
plt.legend(loc='lower right')
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
